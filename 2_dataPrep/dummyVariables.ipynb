# %%
ls
# Out:
# Icon?                   dataSetPrep_v2.ipynb    wave1_gluc_clean.csv
# dataSetPrep.zip         dummyVariables.ipynb    wave1_gluc_cleaned.csv

# %%
import pandas as pd
import numpy as np

# %%
wave1_gluc = pd.read_csv('wave1_gluc_clean.csv', header=0, na_values=' ', index_col=0)

# %%
wave1_gluc.head()
# Out:
#         AID  H1GI1M  H1GI1Y  H1GI2  H1GI3  H1GI4  H1GI5A  H1GI5B  H1GI5C  \
# 0  57101310      11      76      0   18.0      0       7       7       7
# 1  57103869       1      77      0   18.0      0       7       7       7
# 2  57109625       3      81      1    5.0      0       7       7       7
# 3  57111071       6      81      0   12.0      0       7       7       7
# 4  57113943       1      79      1   10.0      0       7       7       7
#
#    H1GI5D   ...     BST90P22  BST90P23  BST90P24  BST90P25  BST90P26  \
# 0       7   ...            1         3         6     0.956         3
# 1       7   ...            2         3         2     0.922         2
# 2       7   ...            3         1         2     0.912         3
# 3       7   ...            2         1         2     0.929         3
# 4       7   ...            1         3         2     0.904         1
#
#    BST90P27  BST90P28  BST90P29  C_MED  C_JOINT
# 0         2     25000     0.826      0        1
# ...

# %%
wave1_gluc.shape
# Out:
# (5107, 231)

# %%
# list = list(wave1_gluc)

# %%
# list

# %%
catVarList = ['H1GI4',
 'H1GI6A',
 'H1GI6B',
 'H1GI6C',
 'H1GI6D',
 'H1GI6E',
 'H1GI10',
 'H1GI11',
 'H1GI14',
 'H1GI18',
 'H1GI20',
 'H1GI21',
 'H1DA1',
 'H1DA2',
 'H1DA3',
 'H1DA5',
 'H1DA6',
 'H1DA7',
 'H1GH1',
 'H1GH2',
 'H1GH8',
 'H1GH10',
 'H1GH11',
 'H1GH18',
 'H1GH19',
 'H1GH20',
 'H1GH21',
 'H1GH22',
 'H1GH24',
 'H1GH25',
 'H1GH28',
 'H1GH42',
#  'H1GH44', #Remove this as categorical variable
#  'H1GH46', #Remove this as categorical variable
 'H1GH52',
 'H1TS1',
 'H1TS2',
 'H1TS3',
 'H1TS4',
 'H1TS13',
 'H1TS14',
 'H1ED1',
 'H1ED16',
 'H1ED17',
 'H1HS1',
 'H1HS3',
 'H1HS5',
 'H1HS7',
#  'H1RP1', #Remove this as a categorical variable
#  'H1RP4', #Remove this as a cat var
#  'H1RP5', #Remove as a cat var
#  'H1RP6', #Remove as a cat var
#  'H1SE1', #Remove as a cat var
#  'H1SE2', #Remove as a cat var
#  'H1SE3', #Remove as a cat var
#  'H1SE4', #Remove as a cat var
#  'H1FS4', #Remove as a cat var
#  'H1FS6', #Remove as a cat var
#  'H1FS7', #Remove as a cat var
#  'H1FS8', #Remove as a cat var
#  'H1FS11', #Remove as a cat var
 'H1NM1',
 'H1NM2',
 'H1NM13',
#  'H1NM14', #Remove as a cat var
 'H1NF1',
 'H1NF2',
 'H1NF13',
#  'H1NF14', #Remove as cat var
 'H1RM1',
 'H1RM4',
 'H1RM9',
 'H1RM10',
 'H1RM11',
 'H1RM12',
 'H1RM13',
 'H1RM14',
 'H1RF1',
 'H1RF4',
 'H1RF9',
 'H1RF10',
 'H1RF11',
 'H1RF13',
 'H1RF14',
 'H1WP1',
 'H1WP4',
 'H1WP6',
 'H1WP7',
#  'H1WP8', # Remove as cat var
#  'H1WP9', # Remove as cat var
#  'H1WP10', # Remove as cat var
#  'H1WP13', # Remove as cat var
#  'H1WP14', # Remove as cat var
 'H1WP17G',
 'H1WP17H',
 'H1WP17I',
 'H1WP17J',
 'H1WP18F',
 'H1WP18G',
 'H1WP18H',
 'H1WP18I',
 'H1WP18J',
 'H1NR5',
#  'H1NR6', # Remove as cat var
 'H1TO1',
 'H1TO3',
 'H1TO15',
 'H1TO19',
 'H1TO29',
#  'H1TO31', # Remove as cat var
 'H1TO33',
 'H1TO36',
 'H1DS1',
 'H1DS2',
 'H1DS3',
 'H1DS5',
 'H1DS7',
 'H1JO9',
 'H1JO15',
 'H1MP1',
 'H1MP2',
 'H1MP3',
 'H1MP4',
 'H1FP1',
 'H1FP2',
 'H1FP3',
 'H1FP6',
 'H1FP8',
 'H1SU1',
 'H1SU2',
 'H1SU4',
 'H1SU5',
 'H1SU6',
 'H1SU7',
#  'H1PA1', # Remove as cat var
#  'H1PA4', # Remove as cat var
#  'H1PR3', # Remove as cat var
#  'H1PR4', # Remove as cat var
#  'H1PR5', # Remove as cat var
#  'H1PR7', # Remove as cat var
#  'H1PR8', # Remove as cat var
 'H1NB2',
 'H1RE1',
 'H1RE3',
 'H1RE6',
 'H1EE12',
 'BST90P01',
 'BST90P02',
 'BST90P04',
 'BST90P05',
 'BST90P08',
 'BST90P10',
 'BST90P11',
 'BST90P13',
 'BST90P19',
 'BST90P20',
 'BST90P22',
 'BST90P23',
 'BST90P24',
 'BST90P26',
 'BST90P27',
 'C_MED']

# %%
catVarList
# Out:
# ['H1GI4',
#  'H1GI6A',
#  'H1GI6B',
#  'H1GI6C',
#  'H1GI6D',
#  'H1GI6E',
#  'H1GI10',
#  'H1GI11',
#  'H1GI14',
#  'H1GI18',
#  'H1GI20',
#  'H1GI21',
#  'H1DA1',
#  'H1DA2',
#  'H1DA3',
#  'H1DA5',
#  'H1DA6',
#  'H1DA7',
#  'H1GH1',
#  'H1GH2',
#  'H1GH8',
#  'H1GH10',
#  'H1GH11',
#  'H1GH18',
#  'H1GH19',
#  'H1GH20',
#  'H1GH21',
#  'H1GH22',
#  'H1GH24',
#  'H1GH25',
#  'H1GH28',
#  'H1GH42',
#  'H1GH52',
#  'H1TS1',
#  'H1TS2',
#  'H1TS3',
#  'H1TS4',
#  'H1TS13',
#  'H1TS14',
#  'H1ED1',
#  'H1ED16',
#  'H1ED17',
#  'H1HS1',
#  'H1HS3',
#  'H1HS5',
#  'H1HS7',
#  'H1NM1',
#  'H1NM2',
#  'H1NM13',
#  'H1NF1',
#  'H1NF2',
#  'H1NF13',
#  'H1RM1',
#  'H1RM4',
#  'H1RM9',
#  'H1RM10',
#  'H1RM11',
#  'H1RM12',
#  'H1RM13',
#  'H1RM14',
#  'H1RF1',
#  'H1RF4',
#  'H1RF9',
#  'H1RF10',
#  'H1RF11',
#  'H1RF13',
#  'H1RF14',
#  'H1WP1',
#  'H1WP4',
#  'H1WP6',
#  'H1WP7',
#  'H1WP17G',
#  'H1WP17H',
#  'H1WP17I',
#  'H1WP17J',
#  'H1WP18F',
#  'H1WP18G',
#  'H1WP18H',
# ...

# %%
wave1_gluc_dummies = pd.get_dummies(wave1_gluc, columns=catVarList)

# %%
wave1_gluc_dummies.shape
# Out:
# (5107, 948)

# %%
wave1_gluc_dummies.head()
# Out:
#         AID  H1GI1M  H1GI1Y  H1GI2  H1GI3  H1GI5A  H1GI5B  H1GI5C  H1GI5D  \
# 0  57101310      11      76      0   18.0       7       7       7       7
# 1  57103869       1      77      0   18.0       7       7       7       7
# 2  57109625       3      81      1    5.0       7       7       7       7
# 3  57111071       6      81      0   12.0       7       7       7       7
# 4  57113943       1      79      1   10.0       7       7       7       7
#
#    H1GI5E   ...     BST90P26_3  BST90P26_8  BST90P26_9  BST90P27_1  \
# 0       7   ...              1           0           0           0
# 1       7   ...              0           0           0           0
# 2       7   ...              1           0           0           1
# 3       7   ...              1           0           0           0
# 4       7   ...              0           0           0           0
#
#    BST90P27_2  BST90P27_3  BST90P27_8  BST90P27_9  C_MED_0  C_MED_1
# ...

# %% [markdown]
# Drop irrelevant dummy columns

# %%
dummyDrop = ['H1GI4_6', 'H1GI4_8', 'H1GI6A_6', 'H1GI6A_8', 'H1GI6B_6',
            'H1GI6B_8', 'H1GI6C_6', 'H1GI6C_8', 'H1GI6D_6', 'H1GI6D_8',
            'H1GI6E_6', 'H1GI6E_8', 'H1GI10_6', 'H1GI10_8', 'H1GI11_6',
            'H1GI11_8', 'H1GI14_8', 'H1GI18_6', 'H1GI18_8', 'H1GI20_97',
            'H1GI20_99', 'H1GI21_96', 'H1GI21_97', 'H1GI21_98', 'H1DA1_6',
            'H1DA1_8', 'H1DA2_6', 'H1DA2_8', 'H1DA3_6', 'H1DA3_8', 
             'H1DA5_6', 'H1DA5_8', 'H1DA6_6', 'H1DA6_8', 'H1DA7_6',
             'H1DA7_8', 'H1GH1_6', 'H1GH1_8', 'H1GH2_6', 'H1GH2_8',
            'H1GH8_6', 'H1GH8_8', 'H1GH10_6', 'H1GH10_8', 'H1GH11_6',
            'H1GH11_8', 'H1GH18_6', 'H1GH18_8', 'H1GH18_8', 'H1GH19_8',
            'H1GH20_6', 'H1GH20_8', 'H1GH21_6', 'H1GH21_8', 'H1GH22_6',
            'H1GH22_8', 'H1GH24_6', 'H1GH24_8', 'H1GH25_6', 'H1GH25_8',
            'H1GH28_6', 'H1GH28_8', 'H1GH42_6', 'H1GH42_8', 'H1GH52_6',
            'H1GH52_8', 'H1TS1_6', 'H1TS1_6', 'H1TS2_6', 'H1TS2_8', 
            'H1TS3_6', 'H1TS3_8', 'H1TS4_6', 'H1TS4_8', 'H1TS13_6',
            'H1TS13_8', 'H1TS14_6', 'H1TS14_8', 'H1ED1_6', 'H1ED1_7',
            'H1ED1_8', 'H1ED16_6', 'H1ED16_7', 'H1ED16_8', 'H1ED17_6',
            'H1ED17_7', 'H1ED17_8', 'H1HS1_6', 'H1HS1_8', 'H1HS3_6',
            'H1HS3_8', 'H1HS5_6', 'H1HS5_8', 'H1HS7_6', 'H1HS7_8',
            'H1NM1_6', 'H1NM1_8', 'H1NM13_8', 'H1NF1_6','H1NF1_8', 
             'H1NF13_8', 'H1RM1_10', 'H1RM1_11', 'H1RM1_12', 'H1RM1_96',
             'H1FP1_8', 'H1FP2_6', 'H1FP2_7', 'H1FP2_8', 'H1FP2_9', 'H1FP3_6', 
             'H1FP3_7', 'H1FP3_8', 'H1FP6_6', 'H1FP6_7', 'H1FP6_8', 'H1FP8_97', 
             'H1FP8_98', 'H1SU1_6', 'H1SU1_8', 'H1SU2_6', 'H1SU2_7', 'H1SU2_8', 
             'H1SU4_6', 'H1SU4_8', 'H1SU5_6', 'H1SU5_7', 'H1SU5_8', 'H1SU6_6', 
             'H1SU6_8', 'H1SU7_7', 'H1SU7_8', 'H1NB2_8', 'H1NB2_9', 'H1RE1_96', 
             'H1RE1_98', 'H1RE1_99', 'H1RE3_6', 'H1RE3_7', 'H1RE3_8', 'H1RE6_6', 
             'H1RE6_7', 'H1RE6_8', 'H1EE12_6', 'H1EE12_8', 'BST90P01_8', 
             'BST90P01_9', 'BST90P02_8', 'BST90P02_9', 'BST90P04_8', 'BST90P04_9', 
             'BST90P05_8', 'BST90P05_9', 'BST90P08_8', 'BST90P08_9', 'BST90P10_8', 
             'BST90P10_9', 'BST90P11_8', 'BST90P11_9', 'BST90P13_8', 'BST90P13_9', 
             'BST90P19_8', 'BST90P19_9', 'BST90P20_8', 'BST90P20_9', 'BST90P22_8', 
             'BST90P22_9', 'BST90P23_8', 'BST90P23_9', 'BST90P24_8', 'BST90P24_9', 
             'BST90P26_8', 'BST90P26_9', 'BST90P27_8', 'BST90P27_9']

# %%
wave1_gluc_dummies.drop(dummyDrop, axis=1, inplace=True)

# %%
wave1_gluc_dummies.head()
# Out:
#         AID  H1GI1M  H1GI1Y  H1GI2  H1GI3  H1GI5A  H1GI5B  H1GI5C  H1GI5D  \
# 0  57101310      11      76      0   18.0       7       7       7       7
# 1  57103869       1      77      0   18.0       7       7       7       7
# 2  57109625       3      81      1    5.0       7       7       7       7
# 3  57111071       6      81      0   12.0       7       7       7       7
# 4  57113943       1      79      1   10.0       7       7       7       7
#
#    H1GI5E   ...     BST90P24_5  BST90P24_6  BST90P26_1  BST90P26_2  \
# 0       7   ...              0           1           0           0
# 1       7   ...              0           0           0           1
# 2       7   ...              0           0           0           0
# 3       7   ...              0           0           0           0
# 4       7   ...              0           0           1           0
#
#    BST90P26_3  BST90P27_1  BST90P27_2  BST90P27_3  C_MED_0  C_MED_1
# ...

# %% [markdown]
# Cleaning up data from general intro section

# %%
generalIntroDropList = ['H1GI1M', 'H1GI1Y', 'H1GI2', 'H1GI3', 'H1GI5A',
                       'H1GI5B', 'H1GI5C', 'H1GI5D','H1GI5E', 'H1GI5F', 'H1GI7A',
                       'H1GI7B', 'H1GI7C', 'H1GI7D', 'H1GI7E', 'H1GI7F',
                       'H1GI7G', 'H1GI8', 'H1GI9', 'H1GI12', 'H1GI13M', 
                       'H1GI13Y', 'H1GI15', 'H1GI16M', 'H1GI16Y', 'H1GI19']

# %%
wave1_gluc_dummies.drop(generalIntroDropList, axis=1, inplace=True)

# %%
contexDBDropList = ['MATCH', 'MOVER']

# %%
wave1_gluc_dummies.drop(contexDBDropList, axis=1, inplace=True)

# %%
wave1_gluc_dummies.to_csv('wave1_gluc_dummies.csv', index=False)
